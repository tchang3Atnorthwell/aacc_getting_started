# %% [markdown]
# This is a jupyter notebook. This notebook file will record your data analysis actions and the resulting .ipynb file can be shared with others so that they can replicate and extend your work. If this is your first time, click on the "Run" button to have your computer run through each step of this notebook.

# %% [markdown]
# Download the dataset Chem8.csv here
#
# https://artery.aacc.org/HigherLogic/System/DownloadDocumentFile.ashx?DocumentFileKey=1263a711-f9c2-4988-ac5a-4ba0f402507f

# %% [markdown]
# Challenge #1
#
# For each of the distinct analytes present in this data set, calculate the following:
#
# Count of observations
# Mean
# Median
# Range

# %%
# import key libraries - os allows filesystem operations like listdir()
# pandas is the library that permits "excel" like functionality,(https://pandas.pydata.org/)
# import pandas as pd allows future calls to pandas to be abbreviated pd

import os
import pandas as pd
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'Chem8 Challenges 1-4.ipynb', 'Chem8.csv']

# %%
#import "Chem8.csv" into a pandas dataframe and show a few rows

chem8=pd.read_csv('Chem8.csv')
chem8
# Out:
#                 ID Type   Na   Cl    Cr   BUN  CO2   Ca  Glc    K
# 0       1025953027   IP  152  117  0.65  20.0   24  9.3  146  3.8
# 1       1025954013   IP  143  107  0.46   8.0   24  8.0  163  3.6
# 2       1025954020   IP  131   97  1.74  92.0   21  8.1  168  5.2
# 3       1025954042   ED  141  104  0.64   9.0   26  8.8  103  3.8
# 4       1025954104   IP  150  119  0.41  45.0   17  7.9   79  3.7
# ...            ...  ...  ...  ...   ...   ...  ...  ...  ...  ...
# 181746  9931922981   OP  137   96  2.51  91.0   24  9.3  125  4.8
# 181747  9931922990   OP  138   97  2.15  49.0   25  9.1  230  4.5
# 181748  9931924037   OP  144  109  1.00  32.0   20  9.6  105  4.4
# 181749  9931924072   OP  143  105  1.21  20.0   22  9.9  129  4.4
# 181750  9931924289   OP  141  101  0.56  11.0   26  9.4   91  4.4
#
# [181751 rows x 10 columns]

# %%
# now that the data has been imported into a dataframe, 
# describe() actually answers most of the challenge #1 questions - min, max, std

chem8.describe()
# Out:
#                  ID             Na             Cl             Cr  \
# count  1.817510e+05  181751.000000  181751.000000  181751.000000
# mean   6.253098e+09     138.743743     102.724079       1.246551
# std    3.332224e+09       4.382035       5.209857       1.296582
# min    1.025953e+09      85.000000      54.000000       0.100000
# 25%    2.731301e+09     137.000000     100.000000       0.690000
# 50%    7.626100e+09     139.000000     103.000000       0.900000
# 75%    9.529100e+09     141.000000     105.000000       1.250000
# max    9.931924e+09     183.000000     169.000000      23.340000
#
#                  BUN            CO2             Ca            Glc  \
# count  181751.000000  181751.000000  181751.000000  181751.000000
# mean       23.029250      23.901024       9.123527     122.456432
# std        18.255517       3.884630       0.738406      53.610641
# min         1.000000       3.000000       1.000000      11.000000
# 25%        12.000000      22.000000       8.700000      91.000000
# 50%        17.000000      24.000000       9.200000     107.000000
# 75%        27.000000      26.000000       9.600000     136.000000
# max       273.000000      65.000000      58.100000     990.000000
#
#                    K
# count  181751.000000
# mean        4.247015
# std         0.581276
# min         1.500000
# 25%         3.900000
# 50%         4.200000
# 75%         4.600000
# max        10.000000

# %%
# since median does not come out of the describe(), we'll call it directly

chem8.median()
# Out:
# C:\Users\tchang3\AppData\Local\Temp/ipykernel_14240/3488717398.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   chem8.median()
# ID     7.626100e+09
# Na     1.390000e+02
# Cl     1.030000e+02
# Cr     9.000000e-01
# BUN    1.700000e+01
# CO2    2.400000e+01
# Ca     9.200000e+00
# Glc    1.070000e+02
# K      4.200000e+00
# dtype: float64

# %%
# we can also call mean() directly if we don't want to use describe()

chem8.mean()
# Out:
# C:\Users\tchang3\AppData\Local\Temp/ipykernel_14240/1217168034.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   chem8.mean()
# ID     6.253098e+09
# Na     1.387437e+02
# Cl     1.027241e+02
# Cr     1.246551e+00
# BUN    2.302925e+01
# CO2    2.390102e+01
# Ca     9.123527e+00
# Glc    1.224564e+02
# K      4.247015e+00
# dtype: float64

# %% [markdown]
# Challenge #2
#
# Generate a histogram for each of the analytes in the file.

# %%
# matplotlib is a powerful plotting package that many use for publication quality graphs (https://matplotlib.org/)
# and pyplot allows for a MATLAB-like interface

import matplotlib.pyplot as plt

# %%
# The [''] notation allows us to just call a single column of data

chem8['Na']
# Out:
# 0         152
# 1         143
# 2         131
# 3         141
# 4         150
#          ...
# 181746    137
# 181747    138
# 181748    144
# 181749    143
# 181750    141
# Name: Na, Length: 181751, dtype: int64

# %%
# hist() plots a histogram, but I find the default binning to be poor

plt.hist(chem8['Na'])
# Out:
# (array([4.00000e+00, 2.00000e+00, 6.50000e+01, 1.25000e+03, 1.54320e+04,
#         1.50366e+05, 1.37600e+04, 7.30000e+02, 1.14000e+02, 2.80000e+01]),
#  array([ 85. ,  94.8, 104.6, 114.4, 124.2, 134. , 143.8, 153.6, 163.4,
#         173.2, 183. ]),
#  <BarContainer object of 10 artists>)

# %%
# So we can tell hist() how many bins to use

plt.hist(chem8['Na'],bins=150)
# Out:
# (array([4.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00,
#         0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         5.0000e+00, 6.0000e+00, 0.0000e+00, 9.0000e+00, 8.0000e+00,
#         0.0000e+00, 1.1000e+01, 1.3000e+01, 0.0000e+00, 1.2000e+01,
#         3.2000e+01, 0.0000e+00, 4.0000e+01, 4.9000e+01, 0.0000e+00,
#         5.9000e+01, 0.0000e+00, 8.0000e+01, 1.2900e+02, 0.0000e+00,
#         1.4900e+02, 1.9000e+02, 0.0000e+00, 2.3600e+02, 2.8600e+02,
#         0.0000e+00, 3.7900e+02, 5.2700e+02, 0.0000e+00, 6.4000e+02,
#         8.8800e+02, 0.0000e+00, 1.2700e+03, 1.7080e+03, 0.0000e+00,
#         2.2960e+03, 3.2010e+03, 0.0000e+00, 4.5230e+03, 0.0000e+00,
#         6.2330e+03, 8.5830e+03, 0.0000e+00, 1.1846e+04, 1.5144e+04,
#         0.0000e+00, 1.9536e+04, 2.2670e+04, 0.0000e+00, 2.2997e+04,
#         1.9605e+04, 0.0000e+00, 1.4577e+04, 9.1750e+03, 0.0000e+00,
#         5.2680e+03, 2.9580e+03, 0.0000e+00, 1.7880e+03, 1.1140e+03,
#         0.0000e+00, 7.8100e+02, 5.7100e+02, 0.0000e+00, 4.4400e+02,
#         0.0000e+00, 3.5100e+02, 2.9500e+02, 0.0000e+00, 1.9000e+02,
#         1.5700e+02, 0.0000e+00, 1.1100e+02, 1.0100e+02, 0.0000e+00,
#         8.1000e+01, 6.7000e+01, 0.0000e+00, 6.8000e+01, 4.8000e+01,
#         0.0000e+00, 3.8000e+01, 3.0000e+01, 0.0000e+00, 2.9000e+01,
#         1.8000e+01, 0.0000e+00, 1.2000e+01, 1.8000e+01, 0.0000e+00,
#         1.2000e+01, 0.0000e+00, 1.6000e+01, 9.0000e+00, 0.0000e+00,
#         1.2000e+01, 3.0000e+00, 0.0000e+00, 6.0000e+00, 8.0000e+00,
#         0.0000e+00, 4.0000e+00, 5.0000e+00, 0.0000e+00, 2.0000e+00,
#         1.0000e+00, 0.0000e+00, 4.0000e+00, 0.0000e+00, 0.0000e+00,
#         1.0000e+01, 1.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00]),
#  array([
sns.displot(chem8[chem8.columns[4]],binwidth=0.1)

# %%
sns.displot(chem8[chem8.columns[5]],binwidth=1)

# %%
sns.displot(chem8[chem8.columns[6]],binwidth=1)

# %%
sns.displot(chem8[chem8.columns[7]],binwidth=0.1)

# %%
sns.displot(chem8[chem8.columns[8]],binwidth=1)

# %% [markdown]
# Challenge #3
#
# Determine the pairwise correlation of all analytes;
# Plot the pairwise correlation (i.e., regression scatterplot) of all analytes; and
#
# Determine which analytes are most highly correlated.

# %%
# seaborn has tools to quickly look at all of the data

sns.pairplot(chem8)

# %%
# sns.pairplot plots on 2 axes

sns.pairplot(chem8[['Na','K']], kind='reg')

# %%
# but we'll downsample to make the correlations more clear and color the regression line

sns.pairplot(chem8[['Na','K']].sample(n=100), kind='reg', plot_kws={'line_kws':{'color':'red'}})

# %%
# now we can do all of the analytes

sns.pairplot(chem8[chem8.columns[2:]].sample(n=100), kind='reg', plot_kws={'line_kws':{'color':'red'}})

# %% [markdown]
# Challenge #4:
#
# Calculate the anion gap for each row; and
# Find the subset of the data for which the anion gap is "abnormal," which we can define as those values greater than 16 mmol/L.

# %%
# calculations are straightforward in pandas

chem8['AnionGap']=chem8['Na']+chem8['K']-chem8['Cl']-chem8['CO2']
chem8
# Out:
#                 ID Type   Na   Cl    Cr   BUN  CO2   Ca  Glc    K  AnionGap
# 0       1025953027   IP  152  117  0.65  20.0   24  9.3  146  3.8      14.8
# 1       1025954013   IP  143  107  0.46   8.0   24  8.0  163  3.6      15.6
# 2       1025954020   IP  131   97  1.74  92.0   21  8.1  168  5.2      18.2
# 3       1025954042   ED  141  104  0.64   9.0   26  8.8  103  3.8      14.8
# 4       1025954104   IP  150  119  0.41  45.0   17  7.9   79  3.7      17.7
# ...            ...  ...  ...  ...   ...   ...  ...  ...  ...  ...       ...
# 181746  9931922981   OP  137   96  2.51  91.0   24  9.3  125  4.8      21.8
# 181747  9931922990   OP  138   97  2.15  49.0   25  9.1  230  4.5      20.5
# 181748  9931924037   OP  144  109  1.00  32.0   20  9.6  105  4.4      19.4
# 181749  9931924072   OP  143  105  1.21  20.0   22  9.9  129  4.4      20.4
# 181750  9931924289   OP  141  101  0.56  11.0   26  9.4   91  4.4      18.4
#
# [181751 rows x 11 columns]

# %%
# you can add limits to select subsets of data

chem8[chem8['AnionGap']>16]
# Out:
#                 ID Type   Na   Cl    Cr   BUN  CO2   Ca  Glc    K  AnionGap
# 2       1025954020   IP  131   97  1.74  92.0   21  8.1  168  5.2      18.2
# 4       1025954104   IP  150  119  0.41  45.0   17  7.9   79  3.7      17.7
# 6       1025954137   IP  138  101  0.89  27.0   22  9.1  199  3.5      18.5
# 7       1025954141   IP  140  106  0.54   4.0   19  8.8  109  3.1      18.1
# 8       1025954165   ED  140  102  0.93  14.0   22  9.3   82  4.3      20.3
# ...            ...  ...  ...  ...   ...   ...  ...  ...  ...  ...       ...
# 181746  9931922981   OP  137   96  2.51  91.0   24  9.3  125  4.8      21.8
# 181747  9931922990   OP  138   97  2.15  49.0   25  9.1  230  4.5      20.5
# 181748  9931924037   OP  144  109  1.00  32.0   20  9.6  105  4.4      19.4
# 181749  9931924072   OP  143  105  1.21  20.0   22  9.9  129  4.4      20.4
# 181750  9931924289   OP  141  101  0.56  11.0   26  9.4   91  4.4      18.4
#
# [103502 rows x 11 columns]
